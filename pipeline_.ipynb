# %%
# %%bash
# fastqc -help
# Out:
#             FastQC - A high throughput sequence QC analysis tool
#
# SYNOPSIS
#
# 	fastqc seqfile1 seqfile2 .. seqfileN
#
#     fastqc [-o output dir] [--(no)extract] [-f fastq|bam|sam]
#            [-c contaminant file] seqfile1 .. seqfileN
#
# DESCRIPTION
#
#     FastQC reads a set of sequence files and produces from each one a quality
#     control report consisting of a number of different modules, each one of
#     which will help to identify a different potential type of problem in your
#     data.
#
#     If no files to process are specified on the command line then the program
#     will start as an interactive graphical application.  If files are provided
#     on the command line then the program will run with no user interaction
#     required.  In this mode it is suitable for inclusion into a standardised
#     analysis pipeline.
#
#     The options for the program as as follows:
#
#     -h --help       Print this help file and exit
#
#     -v --version    Print the version of the program and exit
#
#     -o --outdir     Create all output files in the specified output directory.
#                     Please note that this directory must exist as the program
#                     will not create it.  If this option is not set then the
#                     output file for each sequence file is created in the same
#                     directory as the sequence file which was processed.
#
#     --casava        Files come from raw casava output. Files in the same sample
#                     group (differing only by the group number) will be analysed
#                     as a set rather than individually. Sequences with the filter
#                     flag set in the header will be excluded from the analysis.
#                     Files must have the same names given to them by casava
#                     (including being gzipped and ending with .gz) otherwise they
#                     won't be grouped together correctly.
#
#     --nano          Files come from nanopore sequences and are in fast5 format. In
#                     this mode you can pass in directories to process and the program
#                     will take in all fast5 files within those directories and produce
#                     a single output file from the sequences found in all files.
#
#     --nofilter      If running with --casava then don't remove read flagged by
#                     casava as poor quality when performing the QC analysis.
#
#     --extract       If set then the zipped output file will be uncompressed in
#                     the same directory after it has been created.  By default
#                     this option will be set if fastqc is run in non-interactive
#                     mode.
#
#     -j --java       Provides the full path to the java binary you want to use to
#                     launch fastqc. If not supplied then java is assumed to be in
#                     your path.
#
#     --noextract     Do not uncompress the output file after creating it.  You
#                     should set this option if you do not wish to uncompress
#                     the output when running in non-interactive mode.
#
#     --nogroup       Disable grouping of bases for reads >50bp. All reports will
#                     show data for every base in the read.  WARNING: Using this
#                     option will cause fastqc to crash and burn if you use it on
#                     really long reads, and your plots may end up a ridiculous size.
#                     You have been warned!
#
#     --min_length    Sets an artificial lower limit on the length of the sequence
#                     to be shown in the report.  As long as you set this to a value
#                     greater or equal to your longest read length then this will be
#                     the sequence length used to create your read groups.  This can
#                     be useful for making directly comaparable statistics from
#                     datasets with somewhat variable read lengths.
#
#     -f --format     Bypasses the normal sequence file format detection and
#                     forces the program to use the specified format.  Valid
#                     formats are bam,sam,bam_mapped,sam_mapped and fastq
#
#     -t --threads    Specifies the number of files which can be processed
#                     simultaneously.  Each thread will be allocated 250MB of
#                     memory so you shouldn't run more threads than your
#                     available memory will cope with, and not more than
#                     6 threads on a 32 bit machine
#
#     -c              Specifies a non-default file which contains the list of
#     --contaminants  contaminants to screen overrepresented sequences against.
#                     The file must contain sets of named contaminants in the
#                     form name[tab]sequence.  Lines prefixed with a hash will
#                     be ignored.
#
#     -a              Specifies a non-default file which contains the list of
#     --adapters      adapter sequences which will be explicity searched against
#                     the library. The file must contain sets of named adapters
#                     in the form name[tab]sequence.  Lines prefixed with a hash
#                     will be ignored.
#
#     -l              Specifies a non-default file which contains a set of criteria
#     --limits        which will be used to determine the warn/error limits for the
#                     various modules.  This file can also be used to selectively
#                     remove some modules from the output all together.  The format
#                     needs to mirror the default limits.txt file found in the
#                     Configuration folder.
#
#    -k --kmers       Specifies the length of Kmer to look for in the Kmer content
#                     module. Specified Kmer length must be between 2 and 10. Default
#                     length is 7 if not specified.
#
#    -q --quiet       Supress all progress messages on stdout and only report errors.
#
#    -d --dir         Selects a directory to be used for temporary files written when
#                     generating report images. Defaults to system temp directory if
#                     not specified.
#
# BUGS
#
#     Any bugs in fastqc should be reported either to simon.andrews@babraham.ac.uk
#     or in www.bioinformatics.babraham.ac.uk/bugzilla/

# %%
pwd
# Out:
# '/home/babin/bgi_test_exome'

# %%
ls -lh ./1_input_data/
# Out:
# total 8.4G
# -rw-r--r-- 1 babin babin 4.2G Jun 29 13:25 raw_62_1.fq.gz
# -rw-r--r-- 1 babin babin 4.2G Jun 29 13:42 raw_62_2.fq.gz

# %% [markdown]
# ### 1. Running FastQC

# %%
# %%bash
# fastqc \
# ./1_input_data/raw_62_1.fq.gz \
# ./1_input_data/raw_62_2.fq.gz \
# -q \
# -t 2 \
# -o ./2_fastqc_out/

# %% [markdown]
# #### FastQC plots explanation:

# %% [markdown]
# - https://dnacore.missouri.edu/PDF/FastQC_Manual.pdf
# - https://rtsf.natsci.msu.edu/genomics/tech-notes/fastqc-tutorial-and-faq/

# %% [markdown]
# ### 2. Trimming reads
# - we have poort "Per base sequence content"
# - so we cut out 10 bases from the head
#
# #### trimmomatic manual
# - http://www.usadellab.org/cms/uploads/supplementary/Trimmomatic/TrimmomaticManual_V0.32.pdf
# - http://www.usadellab.org/cms/?page=trimmomatic

# %%
# %%bash
# trimmomatic \
# PE \
# -threads 32 \
# ./1_input_data/raw_62_1.fq.gz \
# ./1_input_data/raw_62_2.fq.gz \
# ./3_trim_out/forw_paired_62_1.fq.gz \
# ./3_trim_out/forw_unpaired_62_1.fq.gz \
# ./3_trim_out/rev_paired_62_2.fq.gz \
# ./3_trim_out/rev_unpaired_62_2.fq.gz \
# HEADCROP:10 \
# MINLEN:36
# Out:
# TrimmomaticPE: Started with arguments:
#  -threads 32 ./1_input_data/raw_62_1.fq.gz ./1_input_data/raw_62_2.fq.gz ./3_trim_out/forw_paired_62_1.fq.gz ./3_trim_out/forw_unpaired_62_1.fq.gz ./3_trim_out/rev_paired_62_2.fq.gz ./3_trim_out/rev_unpaired_62_2.fq.gz HEADCROP:10 MINLEN:36
# Quality encoding detected as phred33
# Input Read Pairs: 48115979 Both Surviving: 48115979 (100.00%) Forward Only Surviving: 0 (0.00%) Reverse Only Surviving: 0 (0.00%) Dropped: 0 (0.00%)
# TrimmomaticPE: Completed successfully

# %% [markdown]
# ### 3. mapping reads on reference by bwa

# %% [markdown]
# #### 3.1 indexing reference sequence

# %%
# %%bash
# bwa index 0_ref/GRCh37_latest_genomic.fna.gz
# Out:
# [bwa_index] Pack FASTA... 61.34 sec
# [bwa_index] Construct BWT for the packed sequence...
# [BWTIncCreate] textLength=6469669378, availableWord=467229400
# [BWTIncConstructFromPacked] 10 iterations done. 99999986 characters processed.
# [BWTIncConstructFromPacked] 20 iterations done. 199999986 characters processed.
# [BWTIncConstructFromPacked] 30 iterations done. 299999986 characters processed.
# [BWTIncConstructFromPacked] 40 iterations done. 399999986 characters processed.
# [BWTIncConstructFromPacked] 50 iterations done. 499999986 characters processed.
# [BWTIncConstructFromPacked] 60 iterations done. 599999986 characters processed.
# [BWTIncConstructFromPacked] 70 iterations done. 699999986 characters processed.
# [BWTIncConstructFromPacked] 80 iterations done. 799999986 characters processed.
# [BWTIncConstructFromPacked] 90 iterations done. 899999986 characters processed.
# [BWTIncConstructFromPacked] 100 iterations done. 999999986 characters processed.
# [BWTIncConstructFromPacked] 110 iterations done. 1099999986 characters processed.
# [BWTIncConstructFromPacked] 120 iterations done. 1199999986 characters processed.
# [BWTIncConstructFromPacked] 130 iterations done. 1299999986 characters processed.
# [BWTIncConstructFromPacked] 140 iterations done. 1399999986 characters processed.
# [BWTIncConstructFromPacked] 150 iterations done. 1499999986 characters processed.
# [BWTIncConstructFromPacked] 160 iterations done. 1599999986 characters processed.
# [BWTIncConstructFromPacked] 170 iterations done. 1699999986 characters processed.
# [BWTIncConstructFromPacked] 180 iterations done. 1799999986 characters processed.
# [BWTIncConstructFromPacked] 190 iterations done. 1899999986 characters processed.
# [BWTIncConstructFromPacked] 200 iterations done. 1999999986 characters processed.
# [BWTIncConstructFromPacked] 210 iterations done. 2099999986 characters processed.
# [BWTIncConstructFromPacked] 220 iterations done. 2199999986 characters processed.
# [BWTIncConstructFromPacked] 230 iterations done. 2299999986 characters processed.
# [BWTIncConstructFromPacked] 240 iterations done. 2399999986 characters processed.
# [BWTIncConstructFromPacked] 250 iterations done. 2499999986 characters processed.
# [BWTIncConstructFromPacked] 260 iterations done. 2599999986 characters processed.
# [BWTIncConstructFromPacked] 270 iterations done. 2699999986 characters processed.
# [BWTIncConstructFromPacked] 280 iterations done. 2799999986 characters processed.
# [BWTIncConstructFromPacked] 290 iterations done. 2899999986 characters processed.
# [BWTIncConstructFromPacked] 300 iterations done. 2999999986 characters processed.
# [BWTIncConstructFromPacked] 310 iterations done. 3099999986 characters processed.
# [BWTIncConstructFromPacked] 320 iterations done. 3199999986 characters processed.
# [BWTIncConstructFromPacked] 330 iterations done. 3299999986 characters processed.
# [BWTIncConstructFromPacked] 340 iterations done. 3399999986 characters processed.
# [BWTIncConstructFromPacked] 350 iterations done. 3499999986 characters processed.
# [BWTIncConstructFromPacked] 360 iterations done. 3599999986 characters processed.
# [BWTIncConstructFromPacked] 370 iterations done. 3699999986 characters processed.
# [BWTIncConstructFromPacked] 380 iterations done. 3799999986 characters processed.
# [BWTIncConstructFromPacked] 390 iterations done. 3899999986 characters processed.
# [BWTIncConstructFromPacked] 400 iterations done. 3999999986 characters processed.
# [BWTIncConstructFromPacked] 410 iterations done. 4099999986 characters processed.
# [BWTIncConstructFromPacked] 420 iterations done. 4199999986 characters processed.
# [BWTIncConstructFromPacked] 430 iterations done. 4299999986 characters processed.
# [BWTIncConstructFromPacked] 440 iterations done. 4399999986 characters processed.
# [BWTIncConstructFromPacked] 450 iterations done. 4499999986 characters processed.
# [BWTIncConstructFromPacked] 460 iterations done. 4599999986 characters processed.
# [BWTIncConstructFromPacked] 470 iterations done. 4699999986 characters processed.
# [BWTIncConstructFromPacked] 480 iterations done. 4799999986 characters processed.
# [BWTIncConstructFromPacked] 490 iterations done. 4899999986 characters processed.
# [BWTIncConstructFromPacked] 500 iterations done. 4999999986 characters processed.
# [BWTIncConstructFromPacked] 510 iterations done. 5099999986 characters processed.
# [BWTIncConstructFromPacked] 520 iterations done. 5199999986 characters processed.
# [BWTIncConstructFromPacked] 530 iterations done. 5299999986 characters processed.
# [BWTIncConstructFromPacked] 540 iterations done. 5399999986 characters processed.
# [BWTIncConstructFromPacked] 550 iterations done. 5499999986 characters processed.
# [BWTIncConstructFromPacked] 560 iterations done. 5599999986 characters processed.
# [BWTIncConstructFromPacked] 570 iterations done. 5699999986 characters processed.
# [BWTIncConstructFromPacked] 580 iterations done. 5799995314 characters processed.
# [BWTIncConstructFromPacked] 590 iterations done. 5893725330 characters processed.
# [BWTIncConstructFromPacked] 600 iterations done. 5977028802 characters processed.
# [BWTIncConstructFromPacked] 610 iterations done. 6051065138 characters processed.
# [BWTIncConstructFromPacked] 620 iterations done. 6116864834 characters processed.
# [BWTIncConstructFromPacked] 630 iterations done. 6175343746 characters processed.
# [BWTIncConstructFromPacked] 640 iterations done. 6227315922 characters processed.
# [BWTIncConstructFromPacked] 650 iterations done. 6273504946 characters processed.
# [BWTIncConstructFromPacked] 660 iterations done. 6314553810 characters processed.
# [BWTIncConstructFromPacked] 670 iterations done. 6351034130 characters processed.
# [BWTIncConstructFromPacked] 680 iterations done. 6383453906 characters processed.
# [BWTIncConstructFromPacked] 690 iterations done. 6412264658 characters processed.
# [BWTIncConstructFromPacked] 700 iterations done. 6437867682 characters processed.
# [BWTIncConstructFromPacked] 710 iterations done. 6460619698 characters processed.
# [bwt_gen] Finished constructing BWT in 715 iterations.
# [bwa_index] 5295.15 seconds elapse.
# [bwa_index] Update BWT... 31.45 sec
# [bwa_index] Pack forward-only FASTA... 45.51 sec
# [bwa_index] Construct SA from BWT and Occ... 2105.74 sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa index 0_ref/GRCh37_latest_genomic.fna.gz
# [main] Real time: 7690.730 sec; CPU: 7539.189 sec

# %%
ls 3_trim_out/
# Out:
# forw_paired_62_1.fq.gz    rev_paired_62_2.fq.gz
# forw_unpaired_62_1.fq.gz  rev_unpaired_62_2.fq.gz

# %% [markdown]
# #### 3.2 mapping reads

# %%
# %%bash
# bwa mem \
# -t 16 \
# 0_ref/GRCh37_latest_genomic.fna.gz \
# 3_trim_out/forw_paired_62_1.fq.gz \
# 3_trim_out/rev_paired_62_2.fq.gz > \
# 4_bwa_out/bgi_exome.sam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (6, 674003, 26, 8)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (231.94, 55.51)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (103, 206, 504)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1306)
# [M::mem_pestat] mean and std.dev: (267.09, 267.33)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1707)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 578.249 CPU sec, 35.902 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (10, 673839, 15, 6)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (92, 239, 857)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2387)
# [M::mem_pestat] mean and std.dev: (301.50, 295.50)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3152)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.37, 55.63)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (137, 177, 962)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2612)
# [M::mem_pestat] mean and std.dev: (323.62, 376.11)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3437)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 573.430 CPU sec, 35.328 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (11, 675423, 23, 6)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (172, 188, 270)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 466)
# [M::mem_pestat] mean and std.dev: (198.91, 73.20)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 564)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.31, 55.62)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (102, 173, 436)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1104)
# [M::mem_pestat] mean and std.dev: (244.45, 215.03)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1438)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 579.660 CPU sec, 35.741 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (9, 671181, 9, 14)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.13, 55.61)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (71, 136, 201)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 461)
# [M::mem_pestat] mean and std.dev: (122.33, 60.91)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 591)
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 593.291 CPU sec, 36.537 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (8, 676541, 18, 9)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (194, 227, 268)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (46, 416)
# [M::mem_pestat] mean and std.dev: (232.75, 55.82)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 490)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (116, 195, 514)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1310)
# [M::mem_pestat] mean and std.dev: (252.81, 233.30)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1708)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 575.790 CPU sec, 35.464 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (2, 677055, 18, 13)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.45, 55.69)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (107, 150, 315)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 731)
# [M::mem_pestat] mean and std.dev: (175.87, 147.73)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 939)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (93, 170, 232)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 510)
# [M::mem_pestat] mean and std.dev: (153.92, 67.97)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 649)
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 577.569 CPU sec, 35.591 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (6, 675489, 11, 8)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.30, 55.57)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (118, 155, 193)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 343)
# [M::mem_pestat] mean and std.dev: (116.67, 69.78)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 418)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 588.329 CPU sec, 36.298 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (10, 676556, 18, 5)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (116, 167, 183)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 317)
# [M::mem_pestat] mean and std.dev: (147.70, 39.48)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 384)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.38, 55.72)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (70, 300, 346)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 898)
# [M::mem_pestat] mean and std.dev: (217.38, 172.51)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1174)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 579.719 CPU sec, 35.674 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (10, 677008, 12, 10)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (102, 169, 201)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 399)
# [M::mem_pestat] mean and std.dev: (152.67, 58.95)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 498)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.21, 55.78)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (90, 178, 263)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 609)
# [M::mem_pestat] mean and std.dev: (170.33, 92.90)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 782)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (181, 803, 980)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2578)
# [M::mem_pestat] mean and std.dev: (725.00, 705.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3546)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 581.110 CPU sec, 35.791 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (3, 675409, 9, 3)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (231.86, 55.55)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 1684212 reads in 607.017 CPU sec, 37.403 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (11, 674310, 13, 12)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (125, 164, 3741)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 10973)
# [M::mem_pestat] mean and std.dev: (1248.45, 1756.24)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 14589)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.19, 55.64)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (78, 155, 202)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 450)
# [M::mem_pestat] mean and std.dev: (135.54, 69.01)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 574)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (99, 138, 786)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2160)
# [M::mem_pestat] mean and std.dev: (350.18, 544.58)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 2847)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 647.491 CPU sec, 39.845 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (8, 674856, 12, 10)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.27, 55.66)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (72, 127, 340)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 876)
# [M::mem_pestat] mean and std.dev: (150.36, 117.20)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1144)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (116, 174, 233)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 467)
# [M::mem_pestat] mean and std.dev: (159.00, 61.35)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 584)
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 601.117 CPU sec, 36.994 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (10, 675400, 16, 9)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (119, 147, 166)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (25, 260)
# [M::mem_pestat] mean and std.dev: (133.22, 33.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 307)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.43, 55.76)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (88, 114, 180)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 364)
# [M::mem_pestat] mean and std.dev: (125.33, 77.10)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 456)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 609.331 CPU sec, 37.435 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (6, 676119, 10, 13)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.00, 55.55)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (98, 769, 971)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2717)
# [M::mem_pestat] mean and std.dev: (398.25, 390.92)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3590)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (99, 158, 822)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2268)
# [M::mem_pestat] mean and std.dev: (319.54, 337.05)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 2991)
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 601.162 CPU sec, 37.016 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (9,

# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 589.214 CPU sec, 36.193 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (7, 675861, 13, 5)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.33, 55.68)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (82, 168, 432)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1132)
# [M::mem_pestat] mean and std.dev: (241.92, 277.04)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1482)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 589.852 CPU sec, 36.387 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (6, 672624, 18, 12)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.17, 55.64)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (155, 350, 1001)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2693)
# [M::mem_pestat] mean and std.dev: (424.20, 338.26)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3539)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (104, 158, 227)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 473)
# [M::mem_pestat] mean and std.dev: (163.55, 82.38)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 596)
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 598.338 CPU sec, 36.825 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (6, 674620, 13, 11)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 266)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (47, 412)
# [M::mem_pestat] mean and std.dev: (231.71, 55.33)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 485)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (136, 227, 396)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 916)
# [M::mem_pestat] mean and std.dev: (200.18, 105.82)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1176)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (76, 112, 192)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 424)
# [M::mem_pestat] mean and std.dev: (98.78, 46.25)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 540)
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 604.485 CPU sec, 37.142 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (14, 668038, 14, 7)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (82, 137, 175)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 361)
# [M::mem_pestat] mean and std.dev: (127.85, 56.43)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 454)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.03, 55.57)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (108, 176, 302)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 690)
# [M::mem_pestat] mean and std.dev: (146.55, 89.51)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 884)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 599.551 CPU sec, 36.854 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (10, 676706, 20, 10)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (126, 172, 326)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 726)
# [M::mem_pestat] mean and std.dev: (172.88, 72.93)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 926)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.01, 55.55)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (137, 278, 355)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 791)
# [M::mem_pestat] mean and std.dev: (192.69, 110.27)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1009)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (97, 132, 193)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 385)
# [M::mem_pestat] mean and std.dev: (124.56, 56.66)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 481)
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 596.353 CPU sec, 36.665 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (10, 676598, 15, 5)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (106, 148, 211)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 421)
# [M::mem_pestat] mean and std.dev: (135.89, 58.13)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 526)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.01, 55.57)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (112, 184, 387)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 937)
# [M::mem_pestat] mean and std.dev: (196.69, 138.63)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1212)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 599.004 CPU sec, 36.787 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (8, 676426, 17, 8)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (231.93, 55.46)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (100, 157, 948)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2644)
# [M::mem_pestat] mean and std.dev: (339.07, 415.97)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3492)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 581.119 CPU sec, 35.718 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (8, 674639, 16, 14)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (231.90, 55.48)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (78, 127, 244)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 576)
# [M::mem_pestat] mean and std.dev: (125.36, 94.62)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 742)
# [M::mem_pestat] analyzing insert size distribution for orientation RR...
# [M::mem_pestat] (25, 50, 75) percentile: (150, 230, 412)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 936)
# [M::mem_pestat] mean and std.dev: (242.33, 152.59)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1198)
# [M::mem_pestat] skip orientation RF
# [M::mem_pestat] skip orientation RR
# [M::mem_process_seqs] Processed 1684212 reads in 586.115 CPU sec, 36.012 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (9, 675185, 19, 5)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.04, 55.55)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (109, 191, 1550)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 4432)
# [M::mem_pestat] mean and std.dev: (792.78, 1080.50)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 5873)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 591.969 CPU sec, 36.431 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (2, 677291, 19, 8)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.23, 55.64)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (101, 177, 291)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 671)
# [M::mem_pestat] mean and std.dev: (158.94, 96.75)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 861)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 585.714 CPU sec, 36.013 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (12, 676597, 25, 8)
# [M::mem_pestat] analyzing insert size distribution for orientation FF...
# [M::mem_pestat] (25, 50, 75) percentile: (126, 157, 202)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 354)
# [M::mem_pestat] mean and std.dev: (145.82, 45.32)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 430)
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.05, 55.53)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (117, 156, 243)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 495)
# [M::mem_pestat] mean and std.dev: (187.40, 99.75)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 621)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation FF
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 593.107 CPU sec, 36.564 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# ...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.18, 55.62)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (7, 120, 353)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1045)
# [M::mem_pestat] mean and std.dev: (178.90, 168.38)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1391)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 578.184 CPU sec, 35.578 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (8, 674491, 11, 6)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 227, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (232.34, 55.72)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (172, 313, 597)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1447)
# [M::mem_pestat] mean and std.dev: (402.45, 393.69)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1977)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 1684212 reads in 667.742 CPU sec, 41.249 real sec
# [M::process] read 1684212 sequences (160000140 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (7, 675490, 16, 4)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (193, 226, 267)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (45, 415)
# [M::mem_pestat] mean and std.dev: (231.82, 55.54)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 489)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (168, 322, 1380)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1,
00)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 484)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 231874 reads in 98.017 CPU sec, 6.045 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -t 16 0_ref/GRCh37_latest_genomic.fna.gz 3_trim_out/forw_paired_62_1.fq.gz 3_trim_out/rev_paired_62_2.fq.gz
# [main] Real time: 2215.663 sec; CPU: 34109.326 sec

# %% [markdown]
# ### 4. dealing with bam file
#
# - manual : http://www.htslib.org/workflow/ (see "WGS/WES Mapping to Variant Calls - Version 1.0")

# %% [markdown]
# #### 4.1 fixmate : clean up read pairing information and flags after bwa mapping
# - `-O` output format
# - `--threads` number of threads to use

# %%
# %%bash
# samtools fixmate -O bam \
# --threads 16 \
# 4_bwa_out/bgi_exome.sam \
# 4_bwa_out/bgi_exome_fixmate_62.bam

# %% [markdown]
# #### 4.2 sort  reads by genome position
# - `-O` output format
# - `--threads` number of threads to use
# - `-m` memory for each thread in Gb
# - `-o` output file

# %%
# %%bash
# samtools sort \
# -O bam \
# --threads 8 \
# -m 1G \
# -o ./4_bwa_out/bgi_exome_fixmate_sorted_62.bam \
# ./4_bwa_out/bgi_exome_fixmate_62.bam
# Out:
# [bam_sort_core] merging from 24 files and 8 in-memory blocks...

# %% [markdown]
# #### 4.3 indexing sorted bam
# - `-@` number of threads to use

# %%
# %%bash
# samtools index \
# ./4_bwa_out/bgi_exome_fixmate_sorted_62.bam \
# -@ 16

# %% [markdown]
# ### 5. bcftools variant calling
#
# - `mpileup` generates genotype likelihoods
# - `call`  makes actuall calling
# - `-f`  reference file
# - `-m`  default calling method
# - `-v`  output only variant sites
# - `-O`  selecting output format 'b' compressed BCF; 'u' uncompressed BCF; 'z' compressed VCF; 'v' uncompressed VCF

# %%
# %%bash
# bcftools mpileup \
# -f 0_ref/GRCh37_latest_genomic.fna \
# ./4_bwa_out/bgi_exome_fixmate_sorted_62.bam \
# --threads 16 \
# | \
# bcftools call \
# -mv -Ov \
# -o ./5_variants/bgi_test.vcf \
# --threads 16
# Out:
# Note: none of --samples-file, --ploidy or --ploidy-file given, assuming all sites are diploid
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250

# %% [markdown]
# ### 7. annotating our vcf with rs IDs from dbsnp vcf

# %% [markdown]
# #### 7.1 compressing vcf file prior to annotation

# %%
# %%bash
# bgzip -c \
# ./6_variants_annot_with_dbsnp/bgi_test.vcf > \
# ./6_variants_annot_with_dbsnp/bgi_test.vcf.gz

# %% [markdown]
# #### 7.2 indexing compressed vcf

# %%
# %%bash
# tabix -p \
# vcf \
# ./6_variants_annot_with_dbsnp/bgi_test.vcf.gz

# %% [markdown]
# #### 7.2 indexing dbsnp vcf

# %%
# %%bash
# tabix -p \
# vcf \
# ./0_annot_dbsnp_37/GRCh37_latest_dbSNP_all.vcf.gz

# %% [markdown]
# #### 7.3 annotating our vcf with rs IDs from dbsnp
# - `-a` file with annotations
# - `-c` columns to take from file with annotations
# - `-o` output file with annotations

# %%
# %%bash
# bcftools annotate \
# -a ./0_annot_dbsnp_37/GRCh37_latest_dbSNP_all.vcf.gz \
# -c ID \
# -o ./6_variants_annot_with_dbsnp/bgi_test_annotated.vcf.gz \
# ./6_variants_annot_with_dbsnp/bgi_test.vcf.gz
